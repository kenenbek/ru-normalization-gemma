# %%
import csv
import re
from collections import defaultdict

def contains_non_cyrillic_letter(text: str) -> bool:
    """
    Checks if a string contains any alphabetic character that is not Cyrillic.
    Returns True if a non-Cyrillic letter is found, False otherwise.
    """
    CYRILLIC_ALPHABET = "абвгдеёжзийклмнопрстуфхцчшщъыьэюяАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ"
    for char in text:
        if char.isalpha():
            if char not in CYRILLIC_ALPHABET:
                return True
    return False

def reconstruct_sentences_from_csv(file_path):
    """
    Reads a CSV file, reconstructs original and normalized sentences,
    and filters out sentences containing Latin words.

    Args:
        file_path (str): The path to the input CSV file.

    Returns:
        list: A list of dictionaries, where each dictionary contains
              a 'sentence' and its 'normalized_sentence'.
    """
    # Use defaultdict to easily append tokens to lists for each sentence_id
    sentences_before = defaultdict(list)
    sentences_after = defaultdict(list)
    latin_sentence_ids = set()

    print(f"Reading and processing file: {file_path}...")

    try:
        with open(file_path, mode='r', encoding='utf-8') as infile:
            reader = csv.DictReader(infile)
            for row in reader:
                sentence_id = int(row['sentence_id'])
                before_token = row['before']
                after_token = row['after']

                # Check for Latin characters in the 'before' token
                if contains_non_cyrillic_letter(before_token):
                    latin_sentence_ids.add(sentence_id)

                # Append tokens to their respective sentences
                sentences_before[sentence_id].append(before_token)
                sentences_after[sentence_id].append(after_token)

    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

    print("Reconstructing and filtering sentences...")
    
    final_results = []
    # Sort by sentence_id to process in order
    sorted_ids = sorted(sentences_before.keys())

    for sentence_id in sorted_ids:
        # Skip sentences that were flagged as containing Latin words
        if sentence_id in latin_sentence_ids:
            continue

        # Join tokens to form the full sentence string
        # This simple join is usually sufficient. For perfect grammar,
        # a more complex joining logic for punctuation would be needed,
        # but this is a robust starting point.
        original_sentence = " ".join(sentences_before[sentence_id])
        normalized_sentence = " ".join(sentences_after[sentence_id])
        
        # A simple post-processing step to fix common spacing issues with punctuation
        for punc in ['.', ',', '?', '!', ')', ':', ';']:
            original_sentence = original_sentence.replace(f' {punc}', punc)
            normalized_sentence = normalized_sentence.replace(f' {punc}', punc)
        for punc in ['(']:
             original_sentence = original_sentence.replace(f'{punc} ', punc)
             normalized_sentence = normalized_sentence.replace(f'{punc} ', punc)


        final_results.append({
            "sentence": original_sentence,
            "normalized_sentence": normalized_sentence
        })

    return final_results

# %%
results = reconstruct_sentences_from_csv("/mnt/d/text-normalization-challenge-russian-language/ru_train.csv/ru_train.csv")
print(f"\nFound {len(results)} Cyrillic-only sentences.\n")
# Out:
# Reading and processing file: /mnt/d/text-normalization-challenge-russian-language/ru_train.csv/ru_train.csv...
# Reconstructing and filtering sentences...
#
# Found 596921 Cyrillic-only sentences.

# %%
results
# Out:
# [{'sentence': 'По состоянию на 1862 год.',
#   'normalized_sentence': 'По состоянию на тысяча восемьсот шестьдесят второй год.'},
#  {'sentence': 'Оснащались латными рукавицами и сабатонами с не длинными носками.',
#   'normalized_sentence': 'Оснащались латными рукавицами и сабатонами с не длинными носками.'},
#  {'sentence': 'В конце 1811 года, вследствие конфликта с проезжим вельможей (графом Салтыковым) вынужден был оставить службу по личному прошению.',
#   'normalized_sentence': 'В конце тысяча восемьсот одиннадцатого года, вследствие конфликта с проезжим вельможей (графом Салтыковым) вынужден был оставить службу по личному прошению.'},
#  {'sentence': 'Севернее Дудинки и северо - восточнее Белочи, в низменной долине Неруссы — урочище Узлив.',
#   'normalized_sentence': 'Севернее Дудинки и северо - восточнее Белочи, в низменной долине Неруссы — урочище Узлив.'},
#  {'sentence': 'Получение информации об адресах, почтовых индексах, странах, городах.',
#   'normalized_sentence': 'Получение информации об адресах, почтовых индексах, странах, городах.'},
#  {'sentence': 'Муниципалитет находится в составе района (комарки) Альто - Дева.',
#   'normalized_sentence': 'Муниципалитет находится в составе района (комарки) Альто - Дева.'},
#  {'sentence': 'Впоследствии многие пилоты, которые были коллегами экипажа рейса 254, были озадачены: как можно было допустить такую ошибку.',
#   'normalized_sentence': 'Впоследствии многие пилоты, которые были коллегами экипажа рейса двести пятьдесят четыре, были озадачены: как можно было допустить такую ошибку.'},
#  {'sentence': 'в 1895 —1896 годах служил на Черноморском флоте на канонерской лодке « Терец ».',
#   'normalized_sentence': 'в тысяча восемьсот девяносто пятом тысяча восемьсот девяносто шестом годах служил на Черноморском флоте на канонерской лодке « Терец ».'},
#  {'sentence': 'Данная поправка была внесена на рассмотрение Съезда народных депутатов РСФСР.',
#   'normalized_sentence': 'Данная поправка была внесена на рассмотрение Съезда народных депутатов р с ф с р.'},
#  {'sentence': 'Революция 1905 года потерпела поражение.',
#   'normalized_sentence': 'Революция тысяча девятьсот пятого года потерпела поражение.'},
#  {'sentence': 'Крепился к наголеннику.',
#   'normalized_sentence': 'Крепился к наголеннику.'},
#  {'sentence': 'Мякоть сбринца желтоватая, а корочка темно - золотого цвета.',
#   'normalized_sentence': 'Мякоть сбринца желтоватая, а корочка темно - золотого цвета.'},
#  {'sentence': 'Шляпка толсто -, реже тонкомясистая, с бугорком или без него.',
#   'normalized_sentence': 'Шляпка толсто -, реже тонкомясистая, с бугорком или без него.'},
#  {'sentence': 'Карапакс сердцевидный коричневого, красновато - коричневого или оливкового цвета.',
#   'normalized_sentence': 'Карапакс сердцевидный коричневого, красновато - коричневого или оливкового цвета.'},
#  {'sentence': 'Он успешно выполняет заказ на убийство Чечена, но попадает в засаду, устроенную людьми Круглого.',
#   'normalized_sentence': 'Он успешно выполняет заказ на убийство Чечена, но попадает в засаду, устроенную людьми Круглого.'},
#  {'sentence': 'Съедобность или токсичность большинства видов не изучены.',
#   'normalized_sentence': 'Съедобность или токсичность большинства видов не изучены.'},
#  {'sentence': '7 октября 2010 года территория Республики Конго отошла к новоучрежденной Браззавильской и Габонской епархии.',
#   'normalized_sentence': 'седьмого октября две тысячи десятого года территория Республики Конго отошла к новоучрежденной Браззавильской и Габонской епархии.'},
#  {'sentence': 'Многие актеры работали за символическую плату.',
#   'normalized_sentence': 'Многие актеры работали за символическую плату.'},
#  {'sentence': '— СПб., 2014. Печатное собрание Лермонтовского музея при Николаевском кавалерийском училище в фонде Библиотеки Пушкинского дома / сост.',
#   'normalized_sentence': '— с п б., две тысячи четырнадцать. Печатное собрание Лермонтовского музея при Николаевском кавалерийском училище в фонде Библиотеки Пушкинского дома / сост.'},
#  {'sentence': 'Немышечные миозины встречаются в разных клетках, в том числе в гладко - мышечных клетках позвоночных.',
#   'normalized_sentence': 'Немышечные миозины встречаются в разных клетках, в том числе в гладко - мышечных клетках позвоночных.'},
#  {'sentence': '— СПб., 2011. Захаров В. А. Летопись жизни и творчества Лермонтова.',
#   'normalized_sentence': '— с п б., две тысячи одиннадцать. Захаров в а Летопись жизни и творчества Лермонтова.'},
#  {'sentence': 'Бандит Круглый не произносит поговорки.',
#   'normalized_sentence': 'Бандит Круглый не произносит поговорки.'},
#  {'sentence': 'Им удалось собрать некоторые сведения, однако, они так и не смогли ответить на вопрос о половой принадлежности великой черепахи.',
#   'normalized_sentence': 'Им удалось собрать некоторые сведения, однако, они так и не смогли ответить на вопрос о половой принадлежности великой черепахи.'},
#  {'sentence': 'Информация была оформлена в виде приказа по Флоту и разослана в 8 часов 31 минуту утра 1 марта.',
#   'normalized_sentence': 'Информация была оформлена в виде приказа по Флоту и разослана в восемь часов тридцати одной минуту утра первого марта.'},
#  {'sentence': 'Семь флотов постоянно патрулируют Окружносеть, чтобы поддерживать ее в порядке и доставлять в Крулл все, что в нее попадет.',
#   'normalized_sentence': 'Семь флотов постоянно патрулируют Окружносеть, чтобы поддерживать ее в порядке и доставлять в Крулл все, что в нее попадет.'},
#  {'sentence': 'Остров является частью провинции Рим региона Лацио.',
#   'normalized_sentence': 'Остров является частью провинции Рим региона Лацио.'},
#  {'sentence': 'Музей находится в пределах венского Арсенала в районе Ландштрассе, недалеко от дворцового комплекса Бельведер.',
#   'normalized_sentence': 'Музей находится в пределах венского Арсенала в районе Ландштрассе, недалеко от дворцового комплекса Бельведер.'},
#  {'sentence': 'В 1843 году, между Карачи и Мултаном стал плавать пароход (около 500 км по реке Инд).',
#   'normalized_sentence': 'В тысяча восемьсот сорок третьем году, между Карачи и Мултаном стал плавать пароход (около пятисот километров по реке Инд).'},
#  {'sentence': 'После Павловских реформ, с 1796 по 1802 год, входила в Перекопский уезд Новороссийской губернии.',
#   'normalized_sentence': 'После Павловских реформ, с тысяча семьсот девяносто шестого по тысяча восемьсот второй год, входила в Перекопский уезд Новороссийской губернии.'},
#  {'sentence': 'К 1873 город стал эффективной и хорошо управляемой гаванью.',
#   'normalized_sentence': 'К тысяча восемьсот семьдесят три город стал эффективной и хорошо управляемой гаванью.'},
#  {'sentence': 'Некоторые источники указывают на период 1109 —1112 годов.',
#   'normalized_sentence': 'Некоторые источники указывают на период тысяча сто девятого тысяча сто двенадцатого годов.'},
#  {'sentence': '30 мая 2007 года Российский союз туриндустрии совместно с петербургским журналом « Всемирный следопыт » объявили аналогичную акцию — « Семь чудес России ».',
#   'normalized_sentence': 'тридцатого мая две тысячи седьмого года Российский союз туриндустрии совместно с петербургским журналом « Всемирный следопыт » объявили аналогичную акцию — « Семь чудес России ».'},
#  {'sentence': 'Сингл достиг шестнадцатой позиции в российском радиочарте.',
#   'normalized_sentence': 'Сингл достиг шестнадцатой позиции в российском радиочарте.'},
#  {'sentence': '— СПб.: Тип.', 'normalized_sentence': '— с п б.: Тип.'},
#  {'sentence': 'Идеи Галуа были отвергнуты современниками и опубликованы посмертно Лиувиллем в 1846 году.',
#   'normalized_sentence': 'Идеи Галуа были отвергнуты современниками и опубликованы посмертно Лиувиллем в тысяча восемьсот сорок шестом году.'},
#  {'sentence': 'Многолетнее растение высотой от 25 — 80 см. Корневище укороченное, почти неразвитое с пучком обильных тонких шнуровидных мочек.',
#   'normalized_sentence': 'Многолетнее растение высотой от двадцати пяти до восемьдесят сантиметров Корневище укороченное, почти неразвитое с пучком обильных тонких шнуровидных мочек.'},
#  {'sentence': 'Степень выраженности симптомов в значительной мере определяется распространенностью и остротой прогрессирования процесса.',
#   'normalized_sentence': 'Степень выраженности симптомов в значительной мере определяется распространенностью и остротой прогрессирования процесса.'},
#  {'sentence': 'Огромная многонациональная империя, занимающая обширное пространство между Круглым Морем и джунглями Говандолэнда.',
#   'normalized_sentence': 'Огромная многонациональная империя, занимающая обширное пространство между Круглым Морем и джунглями Говандолэнда.'},
#  {'sentence': 'Дифференцировать необходимо с делирием, опухолями головного мозга, шизофренией, острыми симптоматическими психозами.',
#   'normalized_sentence': 'Дифференцировать необходимо с делирием, опухолями головного мозга, шизофренией, острыми симптоматическими психозами.'},
#  {'sentence': 'Меры общего характера включают постельный режим, ингаляцию кислорода и прием нестероидных противовоспалительных средств (НПВС).',
#   'normalized_sentence': 'Меры общего характера включают постельный режим, ингаляцию кислорода и прием нестероидных противовоспалительных средств (н п в с).'},
#  {'sentence': '— Виктор СухоруковТак же принять участие в съемках третьей части согласен и оператор Сергей Астахов.',
#   'normalized_sentence': '— Виктор СухоруковТак же принять участие в съемках третьей части согласен и оператор Сергей Астахов.'},
#  {'sentence': 'Мнение Попа получило широкое распространение, с тех пор « Двойное вероломство » ставилась лишь однажды.',
#   'normalized_sentence': 'Мнение Попа получило широкое распространение, с тех пор « Двойное вероломство » ставилась лишь однажды.'},
#  {'sentence': 'ред.: В. В. Маланин — Пермь: Изд - во Перм.',
#   'normalized_sentence': 'ред.: в в Маланин — Пермь: Изд - во Перм.'},
#  {'sentence': 'Некоторые люди, обладающие повышенным религиозным чувством и философскими интересами, также могут страдать височной эпилепсией.',
#   'normalized_sentence': 'Некоторые люди, обладающие повышенным религиозным чувством и философскими интересами, также могут страдать височной эпилепсией.'},
#  {'sentence': 'В Русском варианте Аквамена называют Какаменом.',
#   'normalized_sentence': 'В Русском варианте Аквамена называют Какаменом.'},
#  {'sentence': 'Вера Арсеньевна Белошапкова умерла в 1996 году в Москве.',
#   'normalized_sentence': 'Вера Арсеньевна Белошапкова умерла в тысяча девятьсот девяносто шестом году в Москве.'},
#  {'sentence': '9 марта Гаскойн провел допрос Сюзанны Уэллс в « Ньюгейте », в результате которого она подтвердила новую версию Холл.',
#   'normalized_sentence': 'девятое марта Гаскойн провел допрос Сюзанны Уэллс в « Ньюгейте », в результате которого она подтвердила новую версию Холл.'},
#  {'sentence': 'В 1938 году Киньдюшев был призван на службу в Рабоче - крестьянскую Красную Армию.',
#   'normalized_sentence': 'В тысяча девятьсот тридцать восьмом году Киньдюшев был призван на службу в Рабоче - крестьянскую Красную Армию.'},
#  {'sentence': 'Прикорневые листья на длинных черешках, листовые пластинки от 2 - 3 см в диаметре, серцевидно - округлой формы, до основания рассеченные.',
#   'normalized_sentence': 'Прикорневые листья на длинных черешках, листовые пластинки от 2 до 3 см в диаметре, серцевидно - округлой формы, до основания рассеченные.'},
#  {'sentence': 'Цветет в июле и августе.',
#   'normalized_sentence': 'Цветет в июле и августе.'},
#  {'sentence': 'Выдвинувшись с своими саперами навстречу врагу, он заминировал лощину и устроил засаду.',
#   'normalized_sentence': 'Выдвинувшись с своими саперами навстречу врагу, он заминировал лощину и устроил засаду.'},
#  {'sentence': 'Николай Семенович Васильченко (род.',
#   'normalized_sentence': 'Николай Семенович Васильченко (род.'},
#  {'sentence': 'Дик Свааб « Мы — это наш мозг.',
#   'normalized_sentence': 'Дик Свааб « Мы — это наш мозг.'},
#  {'sentence': 'Еще с мая 1941 года участие населения Крита в боях против германских парашютистов стало перерастать в партизанское движение.',
#   'normalized_sentence': 'Еще с мая тысяча девятьсот сорок первого года участие населения Крита в боях против германских парашютистов стало перерастать в партизанское движение.'},
#  {'sentence': 'Джон Стюарт, 1-й маркиз Бьют, стал носить этот титул с 1776 года.',
#   'normalized_sentence': 'Джон Стюарт, первый маркиз Бьют, стал носить этот титул с тысяча семьсот семьдесят шестого года.'},
#  {'sentence': 'На Плоском Мире восьмисторонняя призма способна расщепить черный цвет на самые различные оттенки.',
#   'normalized_sentence': 'На Плоском Мире восьмисторонняя призма способна расщепить черный цвет на самые различные оттенки.'},
#  {'sentence': 'Агатовая Империя занимает почти весь Противовесный Континент.',
#   'normalized_sentence': 'Агатовая Империя занимает почти весь Противовесный Континент.'},
#  {'sentence': 'Арис представлял себя населению в качестве « майора артиллерии ».',
#   'normalized_sentence': 'Арис представлял себя населению в качестве « майора артиллерии ».'},
#  {'sentence': '— М.: МЕДпресс - информ, 2015. — Т. 2. (предш.',
#   'normalized_sentence': '— м: МЕДпресс - информ, две тысячи пятнадцать. — т два. (предш.'},
#  {'sentence': 'Здесь к его отряду примкнула действовавшая в этом регионе группа врача Хутаса « ЭЭ » (« Эллас - Элефтерия », то есть « Греция - Свобода »).',
#   'normalized_sentence': 'Здесь к его отряду примкнула действовавшая в этом регионе группа врача Хутаса « э э » (« Эллас - Элефтерия », то есть « Греция - Свобода »).'},
#  {'sentence': '13 января 2016 года в СМИ появилась информация о том, что Мондрагон пытался покончить жизнь самоубийством, приняв большую дозу антидепрессантов.',
#   'normalized_sentence': 'тринадцатого января две тысячи шестнадцатого года в СМИ появилась информация о том, что Мондрагон пытался покончить жизнь самоубийством, приняв большую дозу антидепрессантов.'},
#  {'sentence': 'Сэр Исаак Ньютон на грани плоского мира.',
#   'normalized_sentence': 'Сэр Исаак Ньютон на грани плоского мира.'},
#  {'sentence': 'Уходя от итальянских войск, которые искали парашютистов, они выбрались на холмы, где наткнулись на партизан Ариса Велухиотиса.',
#   'normalized_sentence': 'Уходя от итальянских войск, которые искали парашютистов, они выбрались на холмы, где наткнулись на партизан Ариса Велухиотиса.'},
#  {'sentence': 'С 1995 — во второй польской лиге за « Вигры ».',
#   'normalized_sentence': 'С тысяча девятьсот девяносто пять — во второй польской лиге за « Вигры ».'},
#  {'sentence': 'Группе 8 партизан ЭДЕС, которой командовал адъютант Зерваса М. Миридакис, было поручено обнаружить и нейтрализовать ДЗОТ.',
#   'normalized_sentence': 'Группе восемь партизан ЭДЕС, которой командовал адъютант Зерваса м Миридакис, было поручено обнаружить и нейтрализовать д з о т.'},
#  {'sentence': '1914 — Участник Первой мировой войны.',
#   'normalized_sentence': 'тысяча девятьсот четырнадцать — Участник Первой мировой войны.'},
#  {'sentence': 'Через реку протягивалась железная цепь.',
#   'normalized_sentence': 'Через реку протягивалась железная цепь.'},
#  {'sentence': 'Почвы Польши преимущественно малоплодородны.',
#   'normalized_sentence': 'Почвы Польши преимущественно малоплодородны.'},
#  {'sentence': 'Зервас приписывал эту атаку своему брату Алекосу, а Майерс — Комниносу Пиромаглу.',
#   'normalized_sentence': 'Зервас приписывал эту атаку своему брату Алекосу, а Майерс — Комниносу Пиромаглу.'},
#  {'sentence': 'Франта, который носил дублет цвета красного вина и рубашку с кружевным жабо.',
#   'normalized_sentence': 'Франта, который носил дублет цвета красного вина и рубашку с кружевным жабо.'},
#  {'sentence': 'Проверено 22 марта 2010. Архивировано из первоисточника 11 апреля 2012. Максим Коваль: " Стараюсь совершенствоваться " (рус.).',
#   'normalized_sentence': 'Проверено двадцать второго марта две тысячи десятого года. Архивировано из первоисточника одиннадцатого апреля две тысячи двенадцатого года. Максим Коваль: " Стараюсь совершенствоваться " (рус.).'},
#  {'sentence': 'Позднее, когда было обнаружено больше остатков, стало понятно, что « маленький бродяга » был не ящерицей, а черепахой.',
#   'normalized_sentence': 'Позднее, когда было обнаружено больше остатков, стало понятно, что « маленький бродяга » был не ящерицей, а черепахой.'},
#  {'sentence': 'Так, его временное население в летний сезон оценивается в 60 тысяч человек.',
#   'normalized_sentence': 'Так, его временное население в летний сезон оценивается в шестьдесят тысяч человек.'},
#  {'sentence': 'ТЕЛЕ ПРЕТ - А - ПОРТЕ — Общество — Новая ГазетаОРТ клонировало программу « Время » Дибров ушел на ОРТ делать телеигру и ночной эфир.',
#   'normalized_sentence': 'ТЕЛЕ ПРЕТ - А - ПОРТЕ — Общество — Новая ГазетаОРТ клонировало программу « Время » Дибров ушел на ОРТ делать телеигру и ночной эфир.'},
#  {'sentence': 'Мысли о семи грехах навевал и сам город.',
#   'normalized_sentence': 'Мысли о семи грехах навевал и сам город.'},
#  {'sentence': 'Красный сари — традиционная одежда для невест в индийской культуре.',
#   'normalized_sentence': 'Красный сари — традиционная одежда для невест в индийской культуре.'},
#  {'sentence': 'Максим Коваль (рус.).',
#   'normalized_sentence': 'Максим Коваль (рус.).'},
#  {'sentence': 'Песня была выпущена 26 ноября 2013 года.',
#   'normalized_sentence': 'Песня была выпущена двадцать шестого ноября две тысячи тринадцатого года.'},
#  {'sentence': 'Пока Шэнк пробивается через церковь, Анджело обстреливает его с колокольни ракетной пусковой установкой.',
#   'normalized_sentence': 'Пока Шэнк пробивается через церковь, Анджело обстреливает его с колокольни ракетной пусковой установкой.'},
#  {'sentence': 'В соответствии с системой родства башкир на вдове мог также жениться старший племянник, двоюродный брат или другой родственник покойного мужа.',
#   'normalized_sentence': 'В соответствии с системой родства башкир на вдове мог также жениться старший племянник, двоюродный брат или другой родственник покойного мужа.'},
#  {'sentence': 'К вступившему в брак с вдовой переходили дети покойного, его имущество, социальный статус, права и обязанности.',
#   'normalized_sentence': 'К вступившему в брак с вдовой переходили дети покойного, его имущество, социальный статус, права и обязанности.'},
#  {'sentence': 'Все производство осуществлялось вручную, единственным механизмом, установленным в мастерской, была ручная машина для выделки шоколада.',
#   'normalized_sentence': 'Все производство осуществлялось вручную, единственным механизмом, установленным в мастерской, была ручная машина для выделки шоколада.'},
#  {'sentence': 'Так как при дворе говорили только по - немецки, стали искать немецкого инструктора.',
#   'normalized_sentence': 'Так как при дворе говорили только по - немецки, стали искать немецкого инструктора.'},
#  {'sentence': 'Какой рубеж прошла Россия?',
#   'normalized_sentence': 'Какой рубеж прошла Россия?'},
#  {'sentence': 'Команда от сезона к сезону выступала с переменным успехом.',
#   'normalized_sentence': 'Команда от сезона к сезону выступала с переменным успехом.'},
#  {'sentence': 'Михаил Афанасьевич Булгаков.',
#   'normalized_sentence': 'Михаил Афанасьевич Булгаков.'},
#  {'sentence': 'яз., 1989. — С. 198. — 12 500 экз.',
#   'normalized_sentence': 'яз., тысяча девятьсот восемьдесят девять. — с сто девяносто восемь. — двенадцать тысяч пятьсот э к з.'},
#  {'sentence': 'Ресурсы поверхностных вод СССР: Гидрологическая изученность.',
#   'normalized_sentence': 'Ресурсы поверхностных вод с с с р: Гидрологическая изученность.'},
#  {'sentence': 'Черенки срезают ниже листа.',
#   'normalized_sentence': 'Черенки срезают ниже листа.'},
#  {'sentence': 'Создание организации было санкционировано германской Службой безопасности (СД) и непосредственно подчинялась Гестапо.',
#   'normalized_sentence': 'Создание организации было санкционировано германской Службой безопасности (с д) и непосредственно подчинялась Гестапо.'},
#  {'sentence': 'Кроме того, данное слово означает украшение, состоящее из белого пера с боку черного шлема, которое носили воины.',
#   'normalized_sentence': 'Кроме того, данное слово означает украшение, состоящее из белого пера с боку черного шлема, которое носили воины.'},
#  {'sentence': 'Как правило, их вплетали в волосы или использовали в виде венков.',
#   'normalized_sentence': 'Как правило, их вплетали в волосы или использовали в виде венков.'},
#  {'sentence': 'Озера в Карелии занимают от 12 —  13 % суши (озерность не уступает финляндской).',
#   'normalized_sentence': 'Озера в Карелии занимают от двенадцати до тринадцать процентов суши (озерность не уступает финляндской).'},
#  {'sentence': '— Л.: Наука, 1985. — 621 с. Стасевич К. Как хищные растения подружились с летучими мышами: [ арх.',
#   'normalized_sentence': '— л: Наука, тысяча девятьсот восемьдесят пять. — шестьсот двадцать одна секунда Стасевич к Как хищные растения подружились с летучими мышами: [ арх.'},
#  {'sentence': 'Численность населения Российской Федерации по муниципальным образованиям на 1 января 2015 года.',
#   'normalized_sentence': 'Численность населения Российской Федерации по муниципальным образованиям на первое января две тысячи пятнадцатого года.'},
#  {'sentence': '12 января — в Новодевичий монастырь, на следующий год опять в тот же день.',
#   'normalized_sentence': 'двенадцатого января — в Новодевичий монастырь, на следующий год опять в тот же день.'},
#  {'sentence': 'Лернед была замужем четыре раза.',
#   'normalized_sentence': 'Лернед была замужем четыре раза.'},
#  {'sentence': 'Далай - лама и многие министры были вынуждены бежать в Индию, где им было предоставлено прибежище.',
#   'normalized_sentence': 'Далай - лама и многие министры были вынуждены бежать в Индию, где им было предоставлено прибежище.'},
#  {'sentence': 'Статуи украшались драгоценными камнями, одеяниями.',
#   'normalized_sentence': 'Статуи украшались драгоценными камнями, одеяниями.'},
#  {'sentence': 'Встречается на склонах горы Виктория.',
#   'normalized_sentence': 'Встречается на склонах горы Виктория.'},
#  {'sentence': '— М.: Рус.', 'normalized_sentence': '— м: Рус.'},
#  {'sentence': 'На то время 22-х летний Шабаль провел лишь пару десятков игр на высшем уровне.',
#   'normalized_sentence': 'На то время двадцать вторых летний Шабаль провел лишь пару десятков игр на высшем уровне.'},
#  {'sentence': 'Разнообразен мир пернатых Карелии, насчитывающий более 260 видов, из которых около 200 — гнездящиеся.',
#   'normalized_sentence': 'Разнообразен мир пернатых Карелии, насчитывающий более двухсот шестидесяти видов, из которых около двухсот — гнездящиеся.'},
#  {'sentence': 'Папий Иерапольский (ок. 60 - 130 гг. н. э.) был епископом Иераполиса в западной Анатолии.',
#   'normalized_sentence': 'Папий Иерапольский (ок. шесть ноль - 130 гг. н. э.) был епископом Иераполиса в западной Анатолии.'},
#  {'sentence': 'После поражения от Англии в полуфинале шабаль покидал поле в слезах.',
#   'normalized_sentence': 'После поражения от Англии в полуфинале шабаль покидал поле в слезах.'},
#  {'sentence': 'Вершиной развития метода является на сегодняшний день комбинация источника фокусированного ультразвука (излучатель вмонтированный в стол) и аппарата МРТ.',
#   'normalized_sentence': 'Вершиной развития метода является на сегодняшний день комбинация источника фокусированного ультразвука (излучатель вмонтированный в стол) и аппарата м р т.'},
#  {'sentence': 'Художники: Франтишек Гудечек, Камиль Лотак, Ян Котик, Ян Сметана, Богумир Матал, а также скульптор Ладислав Зивр и фотограф Мирослав Гак.',
#   'normalized_sentence': 'Художники: Франтишек Гудечек, Камиль Лотак, Ян Котик, Ян Сметана, Богумир Матал, а также скульптор Ладислав Зивр и фотограф Мирослав Гак.'},
#  {'sentence': 'Говорят, что музей подобен айсбергу: 10 % на поверхности — в экспозициях, 90 % — в глубине, в хранении.',
#   'normalized_sentence': 'Говорят, что музей подобен айсбергу: десять процентов на поверхности — в экспозициях, девяносто процентов — в глубине, в хранении.'},
#  {'sentence': 'Его внешность, манера игры и физические данные поспособствовали тому, что игроку дали очень много кличек.',
#   'normalized_sentence': 'Его внешность, манера игры и физические данные поспособствовали тому, что игроку дали очень много кличек.'},
#  {'sentence': 'Вернувшись в Триполи, расположенном в центре полуострова, он налетами пытался подавлять очаги восстания, один за другим.',
#   'normalized_sentence': 'Вернувшись в Триполи, расположенном в центре полуострова, он налетами пытался подавлять очаги восстания, один за другим.'},
#  {'sentence': 'Новым хитом Егора с этого альбома стала песня « Невеста ».',
#   'normalized_sentence': 'Новым хитом Егора с этого альбома стала песня « Невеста ».'},
#  {'sentence': 'Ее вскормила Гера.',
#   'normalized_sentence': 'Ее вскормила Гера.'},
#  {'sentence': 'Главным достижением клуба является победа в национальном чемпионате в 1979 году.',
#   'normalized_sentence': 'Главным достижением клуба является победа в национальном чемпионате в тысяча девятьсот семьдесят девятом году.'},
#  {'sentence': 'Возник у дороги и звался долгое время городом ямщиков, пока не занесло сюда в поисках уединения Петра Ильича Чайковского.',
#   'normalized_sentence': 'Возник у дороги и звался долгое время городом ямщиков, пока не занесло сюда в поисках уединения Петра Ильича Чайковского.'},
#  {'sentence': 'От взрывов были повреждены здания гостиницы, вокзала, множество автомобилей и два поезда.',
#   'normalized_sentence': 'От взрывов были повреждены здания гостиницы, вокзала, множество автомобилей и два поезда.'},
#  {'sentence': 'Провинциальные собрания (фр.',
#   'normalized_sentence': 'Провинциальные собрания (ф р.'},
#  {'sentence': 'Бабочки ведут исключительно дневной образ жизни и активны только в солнечную погоду.',
#   'normalized_sentence': 'Бабочки ведут исключительно дневной образ жизни и активны только в солнечную погоду.'},
#  {'sentence': 'веселый стол, дон.',
#   'normalized_sentence': 'веселый стол, дон.'},
#  {'sentence': 'Структура печени остается нормальной.',
#   'normalized_sentence': 'Структура печени остается нормальной.'},
#  {'sentence': 'Мультиплекс также, помимо демонстрации кино, может предоставлять иные развлечения, позволяя посетителям получить максимум удовольствия.',
#   'normalized_sentence': 'Мультиплекс также, помимо демонстрации кино, может предоставлять иные развлечения, позволяя посетителям получить максимум удовольствия.'},
#  {'sentence': 'Это означает, что ареал котиков вновь расширяется.',
#   'normalized_sentence': 'Это означает, что ареал котиков вновь расширяется.'},
#  {'sentence': 'Синдром получил название в честь английского врача Джона Дауна, впервые описавшего его в 1866 году.',
#   'normalized_sentence': 'Синдром получил название в честь английского врача Джона Дауна, впервые описавшего его в тысяча восемьсот шестьдесят шестом году.'},
#  {'sentence': 'На время Софи - Виктория оставила дочь в покое.',
#   'normalized_sentence': 'На время Софи - Виктория оставила дочь в покое.'},
#  {'sentence': 'Природный талант позволил ему окончить школу за полтора года, вместо положенных трех.',
#   'normalized_sentence': 'Природный талант позволил ему окончить школу за полтора года, вместо положенных трех.'},
#  {'sentence': 'С открытием в 1950-х годах технологий, позволяющих изучать кариотип, стало возможно определить аномалии хромосом, их количество и форму.',
#   'normalized_sentence': 'С открытием в тысяча девятьсот пятидесятых годах технологий, позволяющих изучать кариотип, стало возможно определить аномалии хромосом, их количество и форму.'},
#  {'sentence': 'Проверено 8 ноября 2011. Архивировано из первоисточника 4 июля 2012. « Винтаж »: все, что мы делаем — проекция нашего внутреннего мира.',
#   'normalized_sentence': 'Проверено восьмого ноября две тысячи одиннадцатого года. Архивировано из первоисточника четвертого июля две тысячи двенадцатого года. « Винтаж »: все, что мы делаем — проекция нашего внутреннего мира.'},
#  {'sentence': 'Латинский, русский, английский, немецкий, французский.',
#   'normalized_sentence': 'Латинский, русский, английский, немецкий, французский.'},
#  {'sentence': 'По последним данным отцовский возраст, особенно если старше 42 лет, также увеличивает риск синдрома.',
#   'normalized_sentence': 'По последним данным отцовский возраст, особенно если старше сорока двух лет, также увеличивает риск синдрома.'},
#  {'sentence': 'Наш город Королев М. 2010г.',
#   'normalized_sentence': 'Наш город Королев м две тысячи десятый год'},
#  {'sentence': 'Машины с большой мощностью двигателя требуют шины с более прочной конструкцией, что приближает их к спортивным моделям.',
#   'normalized_sentence': 'Машины с большой мощностью двигателя требуют шины с более прочной конструкцией, что приближает их к спортивным моделям.'},
#  {'sentence': 'Родственники и гости со стороны невесты обычно прибывали на пир свадебный к жениху позже, после прибытия туда молодых.',
#   'normalized_sentence': 'Родственники и гости со стороны невесты обычно прибывали на пир свадебный к жениху позже, после прибытия туда молодых.'},
#  {'sentence': 'Петровский М. С. Книги нашего детства.',
#   'normalized_sentence': 'Петровский м с Книги нашего детства.'},
#  {'sentence': 'Из крупных птиц встречаются орлы, соколы, глухари.',
#   'normalized_sentence': 'Из крупных птиц встречаются орлы, соколы, глухари.'},
#  {'sentence': 'Санд осознает себя главой семьи.',
#   'normalized_sentence': 'Санд осознает себя главой семьи.'},
#  {'sentence': 'Там не было средств массовой информации или рекламы, связанные с организацией с декабря 2009 года.',
#   'normalized_sentence': 'Там не было средств массовой информации или рекламы, связанные с организацией с декабря две тысячи девятого года.'},
#  {'sentence': 'Под юрисдикцией Объединенной великой ложи Англии, три органа управления существуют для этого промежуточного управления.',
#   'normalized_sentence': 'Под юрисдикцией Объединенной великой ложи Англии, три органа управления существуют для этого промежуточного управления.'},
#  {'sentence': 'На третий день после катастрофы он был найден.',
#   'normalized_sentence': 'На третий день после катастрофы он был найден.'},
#  {'sentence': 'В манчестерском объединении лож этой организации есть должность провинциального великого мастера.',
#   'normalized_sentence': 'В манчестерском объединении лож этой организации есть должность провинциального великого мастера.'},
#  {'sentence': 'Проверено 25 октября 2011. Архивировано из первоисточника 24 мая 2012. Анна Плетнева пригласила Волочкову на концерт « Винтажа ».',
#   'normalized_sentence': 'Проверено двадцать пятого октября две тысячи одиннадцатого года. Архивировано из первоисточника двадцать четвертого мая две тысячи двенадцатого года. Анна Плетнева пригласила Волочкову на концерт « Винтажа ».'},
#  {'sentence': 'Кроме того, правый двигатель вырывает 10 метров кромки крыла.',
#   'normalized_sentence': 'Кроме того, правый двигатель вырывает десять метров кромки крыла.'},
#  {'sentence': 'Существует суеверие, что актеров, которые играют положительных героев в экранизациях комиксов про Супермена, настигает одноименное проклятие.',
#   'normalized_sentence': 'Существует суеверие, что актеров, которые играют положительных героев в экранизациях комиксов про Супермена, настигает одноименное проклятие.'},
#  {'sentence': 'Территориальный орган Федеральной службы государственной статистики по Архангельской области.',
#   'normalized_sentence': 'Территориальный орган Федеральной службы государственной статистики по Архангельской области.'},
#  {'sentence': 'Чарльз Крейн потом устроил Томаша Масарика к себе на работу.',
#   'normalized_sentence': 'Чарльз Крейн потом устроил Томаша Масарика к себе на работу.'},
#  {'sentence': 'В сезоне 2005 / 06 « Карпаты » заняли 2 место в Первой лиге и вышли в Высшую лигу, Диого сыграл 10 матчей.',
#   'normalized_sentence': 'В сезоне две тысячи пять / ноль шесть « Карпаты » заняли два место в Первой лиге и вышли в Высшую лигу, Диого сыграл десять матчей.'},
#  {'sentence': 'Они поженились в декабре 1941 года, а в 1943 году у них родилась дочь, тоже получившая имя Патрисия.',
#   'normalized_sentence': 'Они поженились в декабре тысяча девятьсот сорок первого года, а в тысяча девятьсот сорок третьем году у них родилась дочь, тоже получившая имя Патрисия.'},
#  {'sentence': 'Каннинг - Тодд умерла в Энсинитасе (Калифорния) в сентябре 2015 года.',
#   'normalized_sentence': 'Каннинг - Тодд умерла в Энсинитасе (Калифорния) в сентябре две тысячи пятнадцатого года.'},
#  {'sentence': 'Мимолетное: Из воспоминаний о Москве / Княгиня Лидия Васильчикова; [ Вступ и ] публ.',
#   'normalized_sentence': 'Мимолетное: Из воспоминаний о Москве / Княгиня Лидия Васильчикова; [ Вступ и ] публ.'},
#  {'sentence': 'Тогда Ричард разрешил ему пойти к бомбе.',
#   'normalized_sentence': 'Тогда Ричард разрешил ему пойти к бомбе.'},
#  {'sentence': 'Масарик, Томаш Гарриг — Биография.',
#   'normalized_sentence': 'Масарик, Томаш Гарриг — Биография.'},
#  {'sentence': 'Община располагается в 9 км от города Осиек.',
#   'normalized_sentence': 'Община располагается в девяти километрах от города Осиек.'},
#  {'sentence': 'На 80 - тый день после авиакатастрофы Бен попросил Ричарда привести ему « Человека из Теллахасси ».',
#   'normalized_sentence': 'На восемьдесят - тый день после авиакатастрофы Бен попросил Ричарда привести ему « Человека из Теллахасси ».'},
#  {'sentence': 'Покидая зимовки, белощекие казарки мигрируют на восток узкой, так называемой беломорско - балтийской трассой.',
#   'normalized_sentence': 'Покидая зимовки, белощекие казарки мигрируют на восток узкой, так называемой беломорско - балтийской трассой.'},
#  {'sentence': 'Многие деревья 200 — 300 летнего возраста были уничтожены после войны, когда часть парка отдали под строительство частных домов.',
#   'normalized_sentence': 'Многие деревья двести — трехсот летнего возраста были уничтожены после войны, когда часть парка отдали под строительство частных домов.'},
#  {'sentence': 'Вслед за Макгаффни другие изобретатели также стали производить и продавать механические пылесосы.',
#   'normalized_sentence': 'Вслед за Макгаффни другие изобретатели также стали производить и продавать механические пылесосы.'},
#  {'sentence': 'Еще один брат фаворита Екатерины, Иван Семенович, имел внука: Николай Александрович, корнет лейб - гвардии Кавалергардского полка, декабрист.',
#   'normalized_sentence': 'Еще один брат фаворита Екатерины, Иван Семенович, имел внука: Николай Александрович, корнет лейб - гвардии Кавалергардского полка, декабрист.'},
#  {'sentence': 'Персональным тренером является мать - Пантова Виктория, командный тренер - Татьяна Дудченко.',
#   'normalized_sentence': 'Персональным тренером является мать - Пантова Виктория, командный тренер - Татьяна Дудченко.'},
#  {'sentence': 'Затем он извлек пулю, продемонстрировав свои медицинские навыки.',
#   'normalized_sentence': 'Затем он извлек пулю, продемонстрировав свои медицинские навыки.'},
#  {'sentence': 'Гирш Вульфович (Григорий Владимирович) Брауде (1906, Витебск — 1992) — советский инженер и ученый, специалист в области телевизионной техники.',
#   'normalized_sentence': 'Гирш Вульфович (Григорий Владимирович) Брауде (тысяча девятьсот шесть, Витебск — тысяча девятьсот девяносто два) — советский инженер и ученый, специалист в области телевизионной техники.'},
#  {'sentence': 'Родовая усыпальница князей Васильчиковых в деревне Бор на берегу Шелони разрушена.',
#   'normalized_sentence': 'Родовая усыпальница князей Васильчиковых в деревне Бор на берегу Шелони разрушена.'},
#  {'sentence': 'Дата смерти Л. И. Защука не установлена.',
#   'normalized_sentence': 'Дата смерти л и Защука не установлена.'},
#  {'sentence': 'яз., « РУССО », 1994. — С. 23. — 2030 экз.',
#   'normalized_sentence': 'яз., « РУССО », тысяча девятьсот девяносто четыре. — с двадцать три. — две тысячи тридцать э к з.'},
#  {'sentence': 'Следует отметить, что в верхнем течении сибирские реки нередко вскрываются ранее, чем в нижнем, что ведет к образованию ледяных заторов.',
#   'normalized_sentence': 'Следует отметить, что в верхнем течении сибирские реки нередко вскрываются ранее, чем в нижнем, что ведет к образованию ледяных заторов.'},
#  {'sentence': 'В 1981 году части территории Дрицанского сельсовета были переданы Аудриньскому и Кантиниекскому сельским советам.',
#   'normalized_sentence': 'В тысяча девятьсот восемьдесят первом году части территории Дрицанского сельсовета были переданы Аудриньскому и Кантиниекскому сельским советам.'},
#  {'sentence': 'Сборник статей по истории и источниковедению.',
#   'normalized_sentence': 'Сборник статей по истории и источниковедению.'},
#  {'sentence': 'Создан в 2014 году.',
#   'normalized_sentence': 'Создан в две тысячи четырнадцатом году.'},
#  {'sentence': 'Преобладающая национальность — русские (90 %).',
#   'normalized_sentence': 'Преобладающая национальность — русские (девяносто процентов).'},
#  {'sentence': 'Мирная), ныне Могилевской области Белоруссии, в бедной крестьянской семье.',
#   'normalized_sentence': 'Мирная), ныне Могилевской области Белоруссии, в бедной крестьянской семье.'},
#  {'sentence': 'Сын — Бостан Узакпаевич Узакпаев, к. т. н., доцент, декан строительного факультета Ташкентского ИИТа.',
#   'normalized_sentence': 'Сын — Бостан Узакпаевич Узакпаев, к. т. н., доцент, декан строительного факультета Ташкентского ИИТа.'},
#  {'sentence': 'Л. С. Переломова).', 'normalized_sentence': 'л с Переломова).'},
#  {'sentence': 'Люткевич, Владислав Вацлавович.',
#   'normalized_sentence': 'Люткевич, Владислав Вацлавович.'},
#  {'sentence': 'Также есть подъездные пути: на восток к промбазе сыпучих материалов « Автобан - Непецино », на северо - восток к ЗАО « Цемторг ».',
#   'normalized_sentence': 'Также есть подъездные пути: на восток к промбазе сыпучих материалов « Автобан - Непецино », на северо - восток к ЗАО « Цемторг ».'},
#  {'sentence': 'Умер 24 сентября 1977 года в Москве.',
#   'normalized_sentence': 'Умер двадцать четвертого сентября тысяча девятьсот семьдесят седьмого года в Москве.'},
#  {'sentence': 'Награжден орденом Красной Звезды (посмертно).',
#   'normalized_sentence': 'Награжден орденом Красной Звезды (посмертно).'},
#  {'sentence': 'В современной России свадьба обычно совпадает с государственной регистрацией брака.',
#   'normalized_sentence': 'В современной России свадьба обычно совпадает с государственной регистрацией брака.'},
#  {'sentence': 'Население — 7 жителей (2007 год).',
#   'normalized_sentence': 'Население — семь жителей (две тысячи седьмой год).'},
#  {'sentence': '— Самара, 2009. — С. 99. А. Бубнов.',
#   'normalized_sentence': '— Самара, две тысячи девять. — с девяносто девять. а Бубнов.'},
#  {'sentence': 'Также не регистрируются нерелигиозные браки.',
#   'normalized_sentence': 'Также не регистрируются нерелигиозные браки.'},
#  {'sentence': 'Архивировано из первоисточника 22 августа 2011. Всероссийская перепись населения 2002 года.',
#   'normalized_sentence': 'Архивировано из первоисточника двадцать второго августа две тысячи одиннадцатого года. Всероссийская перепись населения две тысячи второго года.'},
#  {'sentence': 'Ф. 1209. Оп.',
#   'normalized_sentence': 'ф тысяча двести девять. Оп.'},
#  {'sentence': 'Проживал и работал в Симферополе.',
#   'normalized_sentence': 'Проживал и работал в Симферополе.'},
#  {'sentence': 'Всероссийская перепись населения 2010 года.',
#   'normalized_sentence': 'Всероссийская перепись населения две тысячи десятого года.'},
#  {'sentence': 'Дабы не ударить в грязь лицом, он вынужден искать источник финансирования и занимает деньги у своего брата — известного мафиозо.',
#   'normalized_sentence': 'Дабы не ударить в грязь лицом, он вынужден искать источник финансирования и занимает деньги у своего брата — известного мафиозо.'},
#  {'sentence': 'Поппер определяет логику научного знания как « теорию теорий ».',
#   'normalized_sentence': 'Поппер определяет логику научного знания как « теорию теорий ».'},
#  {'sentence': '— Л.: Гидрометеоиздат, 1967. — 351 с. Государственный водный реестр РФ: Шабаниха.',
#   'normalized_sentence': '— л: Гидрометеоиздат, тысяча девятьсот шестьдесят семь. — триста пятьдесят одна секунда Государственный водный реестр р ф: Шабаниха.'},
#  {'sentence': 'Также засвидетельствовано скотоводство, в том числе таких животных, как козы и овцы.',
#   'normalized_sentence': 'Также засвидетельствовано скотоводство, в том числе таких животных, как козы и овцы.'},
#  {'sentence': 'В 1917 году выпуск журнала был прекращен.',
#   'normalized_sentence': 'В тысяча девятьсот семнадцатом году выпуск журнала был прекращен.'},
#  {'sentence': 'В конце марта 1920 года принял участие в эвакуации войск ВСЮР из Новороссийска в Севастополь.',
#   'normalized_sentence': 'В конце марта тысяча девятьсот двадцатого года принял участие в эвакуации войск ВСЮР из Новороссийска в Севастополь.'},
#  {'sentence': 'в 1934 —1937 годах район входил в Северо - Донской округ в составе Азово - Черноморского края.',
#   'normalized_sentence': 'в тысяча девятьсот тридцать четвертом тысяча девятьсот тридцать седьмом годах район входил в Северо - Донской округ в составе Азово - Черноморского края.'},
#  {'sentence': 'Джин Симмонс — бас - гитара, вокалПол Стэнли — ритм - гитара, вокал.',
#   'normalized_sentence': 'Джин Симмонс — бас - гитара, вокалПол Стэнли — ритм - гитара, вокал.'},
#  {'sentence': 'Требуется меньшая мощность привода для подъема и опускания полупантографа.',
#   'normalized_sentence': 'Требуется меньшая мощность привода для подъема и опускания полупантографа.'},
#  {'sentence': 'Ландшафт заказника преимущественно представлен смешанным лесом.',
#   'normalized_sentence': 'Ландшафт заказника преимущественно представлен смешанным лесом.'},
#  {'sentence': 'В 2011 году был секвенирован и опубликован геном белощекого хохлатого гиббона.',
#   'normalized_sentence': 'В две тысячи одиннадцатом году был секвенирован и опубликован геном белощекого хохлатого гиббона.'},
#  {'sentence': '« Потемкин » В. С. Лопатин.',
#   'normalized_sentence': '« Потемкин » в с Лопатин.'},
#  {'sentence': 'Однако до 10 % рациона составляют насекомые и другие мелкие животные.',
#   'normalized_sentence': 'Однако до десяти процентов рациона составляют насекомые и другие мелкие животные.'},
#  {'sentence': 'Отличник народного образования республики.',
#   'normalized_sentence': 'Отличник народного образования республики.'},
#  {'sentence': 'Кандидат философских наук.',
#   'normalized_sentence': 'Кандидат философских наук.'},
#  {'sentence': 'с 1927 по 1942 год монеты не чеканились.',
#   'normalized_sentence': 'с тысяча девятьсот двадцать седьмого по тысяча девятьсот сорок второй год монеты не чеканились.'},
#  {'sentence': 'Анна (Лина, 1827 — 1890), жена с 1845 графа Павла Трофимовича Баранова.',
#   'normalized_sentence': 'Анна (Лина, тысяча восемьсот двадцать семь — тысяча восемьсот девяносто), жена с тысячи восьмисот сорока пяти графа Павла Трофимовича Баранова.'},
#  {'sentence': 'Турнир проводился в рамках Зимних Олимпийских игр 1964 года в Австрии.',
#   'normalized_sentence': 'Турнир проводился в рамках Зимних Олимпийских игр тысяча девятьсот шестьдесят четвертого года в Австрии.'},
#  {'sentence': 'Во время этого поста таинство брака также не совершается.',
#   'normalized_sentence': 'Во время этого поста таинство брака также не совершается.'},
#  {'sentence': 'Михаил Васильевич Кречинский — видный мужчина лет под сорок, претендент на руку и сердце Лидочки.',
#   'normalized_sentence': 'Михаил Васильевич Кречинский — видный мужчина лет под сорок, претендент на руку и сердце Лидочки.'},
#  {'sentence': 'Здание обкома КПСС.',
#   'normalized_sentence': 'Здание обкома к п с с.'},
#  {'sentence': 'Вблизи населенного пункта Збережа проник в траншею противника, уничтожил его пулемет с расчетом, который мешал продвижению наших войск.',
#   'normalized_sentence': 'Вблизи населенного пункта Збережа проник в траншею противника, уничтожил его пулемет с расчетом, который мешал продвижению наших войск.'},
#  {'sentence': 'На территории Новой Англии выделяют Белые горы, Зеленые горы, а также хребты Таконик и Беркширы.',
#   'normalized_sentence': 'На территории Новой Англии выделяют Белые горы, Зеленые горы, а также хребты Таконик и Беркширы.'},
#  {'sentence': 'Хоккей: Малая энциклопедия спорта.',
#   'normalized_sentence': 'Хоккей: Малая энциклопедия спорта.'},
#  {'sentence': '13 ноября 1991 года Верховный Совет КАССР принял решение о переименовании Карельской Автономной Советской Социалистической Республики в Республику Карелия.',
#   'normalized_sentence': 'тринадцатого ноября тысяча девятьсот девяносто первого года Верховный Совет КАССР принял решение о переименовании Карельской Автономной Советской Социалистической Республики в Республику Карелия.'},
#  {'sentence': 'В июле вышла первая публичная бета - версия.',
#   'normalized_sentence': 'В июле вышла первая публичная бета - версия.'},
#  {'sentence': 'Турнир проходил в один круг.',
#   'normalized_sentence': 'Турнир проходил в один круг.'},
#  {'sentence': 'Три территории: Нунавут, Северо - Западные территории и Юкон.',
#   'normalized_sentence': 'Три территории: Нунавут, Северо - Западные территории и Юкон.'},
#  {'sentence': 'В 1937 году опубликовал монографию « Неингаляционный наркоз в хирургии », ставшую классическим учебным пособием.',
#   'normalized_sentence': 'В тысяча девятьсот тридцать седьмом году опубликовал монографию « Неингаляционный наркоз в хирургии », ставшую классическим учебным пособием.'},
#  {'sentence': 'Процедура провинциальных законодательных органов подобна процедуре канадской Палаты общин.',
#   'normalized_sentence': 'Процедура провинциальных законодательных органов подобна процедуре канадской Палаты общин.'},
#  {'sentence': '« Свадьбой Кречинского » в исполнении труппы п / у Е. В. Лаврова завершил свой первый сезон (1883/1884 год) постоянный русский театр в Риге.',
#   'normalized_sentence': '« Свадьбой Кречинского » в исполнении труппы п / у е в Лаврова завершил свой первый сезон (тысяча восемьсот восемьдесят три тысяча восемьсот восемьдесят четвертых год) постоянный русский театр в Риге.'},
#  {'sentence': 'Свой первый гол Воукс забил 16 декабря 2006 года в матче против « Джиллингема » (1: 1).',
#   'normalized_sentence': 'Свой первый гол Воукс забил шестнадцатое декабря две тысячи шестого года в матче против « Джиллингема » (один: один).'},
#  {'sentence': 'Сын — Владимир Исаакович Жоров (1924 — 2002) — доктор медицинских наук, профессор.',
#   'normalized_sentence': 'Сын — Владимир Исаакович Жоров (тысяча девятьсот двадцать четыре — две тысячи два) — доктор медицинских наук, профессор.'},
#  {'sentence': 'Еще одной угрозой для тибетской лисицы являются домашние собаки коренных жителей Тибета.',
#   'normalized_sentence': 'Еще одной угрозой для тибетской лисицы являются домашние собаки коренных жителей Тибета.'},
#  {'sentence': 'Английское полотно — копия с эрмитажного.',
#   'normalized_sentence': 'Английское полотно — копия с эрмитажного.'},
#  {'sentence': 'Учился в гимназии и затем на юридическом факультете Афинского университета, откуда был исключен за революционную деятельность.',
#   'normalized_sentence': 'Учился в гимназии и затем на юридическом факультете Афинского университета, откуда был исключен за революционную деятельность.'},
#  {'sentence': '« Свадьба Кречинского », фильм - спектакль Московского драматического театра имени А. С. Пушкина, 1953 год.',
#   'normalized_sentence': '« Свадьба Кречинского », фильм - спектакль Московского драматического театра имени а с Пушкина, тысяча девятьсот пятьдесят третий год.'},
#  {'sentence': 'В списке вратари, сыгравшие не менее 40 % от всего игрового времени их сборной.',
#   'normalized_sentence': 'В списке вратари, сыгравшие не менее сорока процентов от всего игрового времени их сборной.'},
#  {'sentence': '— 911 с. — 100 000 экз.',
#   'normalized_sentence': '— девятьсот одиннадцать секунд — сто тысяч э к з.'},
#  {'sentence': 'Также « Провинция » оказывает полный цикл рекламных услуг.',
#   'normalized_sentence': 'Также « Провинция » оказывает полный цикл рекламных услуг.'},
#  {'sentence': 'Проверено 6 января 2011. Архивировано из первоисточника 14 августа 2011. Лу Лумерик.',
#   'normalized_sentence': 'Проверено шестого января две тысячи одиннадцатого года. Архивировано из первоисточника четырнадцатого августа две тысячи одиннадцатого года. Лу Лумерик.'},
#  {'sentence': 'Кулундинский канал проходит по следующий районам Алтайского края: Каменский, Тюменцевский, Баевский, Благовещенский, Родинский.',
#   'normalized_sentence': 'Кулундинский канал проходит по следующий районам Алтайского края: Каменский, Тюменцевский, Баевский, Благовещенский, Родинский.'},
# ...
#  {'sentence': 'ЦИК зарегистрировала партийный список ОСДП.',
#   'normalized_sentence': 'ЦИК зарегистрировала партийный список о с д п.'},
#  {'sentence': 'Передний край обороны противника проходил по р. Миус.',
#   'normalized_sentence': 'Передний край обороны противника проходил по р. Миус.'},
#  {'sentence': 'Ужасы мертвого городка.',
#   'normalized_sentence': 'Ужасы мертвого городка.'},
#  {'sentence': 'В правой верхней части щита буквами синего цвета указывается название муниципального образования — Большой Луг.',
#   'normalized_sentence': 'В правой верхней части щита буквами синего цвета указывается название муниципального образования — Большой Луг.'},
#  {'sentence': 'Прозвище дали армянские болельщики.',
#   'normalized_sentence': 'Прозвище дали армянские болельщики.'},
#  {'sentence': 'Здесь же в 1717 году, впервые в России, было сварено « лазоревое » стекло.',
#   'normalized_sentence': 'Здесь же в тысяча семьсот семнадцатом году, впервые в России, было сварено « лазоревое » стекло.'},
#  {'sentence': 'Наткнувшись на организованный огонь и подвергаясь непрерывным массированным ударам вражеской авиации, корпус своими главными силами прорваться на Хотынец не смог.',
#   'normalized_sentence': 'Наткнувшись на организованный огонь и подвергаясь непрерывным массированным ударам вражеской авиации, корпус своими главными силами прорваться на Хотынец не смог.'},
#  {'sentence': 'Среди жертв Дровосека были и беременная женщина, и малолетний ребенок, зарубленный прямо на руках у матери.',
#   'normalized_sentence': 'Среди жертв Дровосека были и беременная женщина, и малолетний ребенок, зарубленный прямо на руках у матери.'},
#  {'sentence': 'На второй день для завершения прорыва обороны стали вводиться в бой по частям 23-й танковый и 1-й гвардейский механизированный корпуса.',
#   'normalized_sentence': 'На второй день для завершения прорыва обороны стали вводиться в бой по частям двадцать третий танковый и первый гвардейский механизированный корпуса.'},
#  {'sentence': 'Путевой дневник профессора Теркиля находит его внучка Саманта (Луиза Ломбард).',
#   'normalized_sentence': 'Путевой дневник профессора Теркиля находит его внучка Саманта (Луиза Ломбард).'},
#  {'sentence': 'Названа в честь русского геохимика и минералога, одного из основоположников геохимии Александра Евгеньевича Ферсмана.',
#   'normalized_sentence': 'Названа в честь русского геохимика и минералога, одного из основоположников геохимии Александра Евгеньевича Ферсмана.'},
#  {'sentence': 'Лауреат Сталинской премии второй степени (1950).',
#   'normalized_sentence': 'Лауреат Сталинской премии второй степени (тысяча девятьсот пятьдесят).'},
#  {'sentence': 'Комплексы необходимо составлять так, чтобы они имели смежные согласные и конечную гласную.',
#   'normalized_sentence': 'Комплексы необходимо составлять так, чтобы они имели смежные согласные и конечную гласную.'},
#  {'sentence': 'Проверено 16 февраля 2001. Архивировано из первоисточника 16 февраля 2001. « Глупый стеб, попса...',
#   'normalized_sentence': 'Проверено шестнадцатого февраля две тысячи первого года. Архивировано из первоисточника шестнадцатого февраля две тысячи первого года. « Глупый стеб, попса...'},
#  {'sentence': '1155) должен был стать королем Англии, также под его контроль переходили Анжу, Мэн и Нормандия.',
#   'normalized_sentence': 'тысяча сто пятьдесят пять) должен был стать королем Англии, также под его контроль переходили Анжу, Мэн и Нормандия.'},
#  {'sentence': 'в 1938 —1939 годах. — начальник Главного управления пограничных и внутренних войск НКВД СССР.',
#   'normalized_sentence': 'в тысяча девятьсот тридцать восьмом тысяча девятьсот тридцать девятом годах. — начальник Главного управления пограничных и внутренних войск н к в д с с с р.'},
#  {'sentence': 'Алекса похищают прислужники Имхотепа, который был воскрешен реинкарнацией своей возлюбленной Анк - Су - Намун (Патрисия Веласкес).',
#   'normalized_sentence': 'Алекса похищают прислужники Имхотепа, который был воскрешен реинкарнацией своей возлюбленной Анк - Су - Намун (Патрисия Веласкес).'},
#  {'sentence': 'Они сказали, что некоторые мусульмане начали покидать город, отправляясь в близлежащие горные деревни.',
#   'normalized_sentence': 'Они сказали, что некоторые мусульмане начали покидать город, отправляясь в близлежащие горные деревни.'},
#  {'sentence': 'Широко развиты мел - палеогеновые инфузии гранитоидов (так называемый Андийский батолит), а также неогеновые эффузивы кислого и среднего состава.',
#   'normalized_sentence': 'Широко развиты мел - палеогеновые инфузии гранитоидов (так называемый Андийский батолит), а также неогеновые эффузивы кислого и среднего состава.'},
#  {'sentence': 'В д. Кульгеши расположены: Средняя общеобразовательная школа; ЦСДК; Фельдшерский пункт; Сельская библиотека - филиал Урмарской ЦБС; Магазин Урмарского райпо; Отделение связи.',
#   'normalized_sentence': 'В д. Кульгеши расположены: Средняя общеобразовательная школа; ц с д к; Фельдшерский пункт; Сельская библиотека - филиал Урмарской ц б с; Магазин Урмарского райпо; Отделение связи.'},
#  {'sentence': 'Повествование ведется в некоторых главах от первого лица главным героем, в прочих от третьего лица.',
#   'normalized_sentence': 'Повествование ведется в некоторых главах от первого лица главным героем, в прочих от третьего лица.'},
#  {'sentence': 'Отличается торчащей вперед беззубой оконечностью нижней челюсти.',
#   'normalized_sentence': 'Отличается торчащей вперед беззубой оконечностью нижней челюсти.'},
#  {'sentence': 'Морская береговая линия имеет длину около 128 км, суммарная площадь лагун доходит до 22 000 га.',
#   'normalized_sentence': 'Морская береговая линия имеет длину около ста двадцати восьми километров, суммарная площадь лагун доходит до двадцати двух тысяч гектаров'},
#  {'sentence': '1. Общий ход военных действий во втором периоде Великой Отечественной войны.',
#   'normalized_sentence': 'один. Общий ход военных действий во втором периоде Великой Отечественной войны.'},
#  {'sentence': 'Также климат меняется при удалении от океана на восток в Анды.',
#   'normalized_sentence': 'Также климат меняется при удалении от океана на восток в Анды.'},
#  {'sentence': 'Административный центр префектуры также называется Киото.',
#   'normalized_sentence': 'Административный центр префектуры также называется Киото.'},
#  {'sentence': 'Воспоминания участников битвы за Ленинград / сост.: Я. Ф. Потехин.',
#   'normalized_sentence': 'Воспоминания участников битвы за Ленинград / сост.: я ф Потехин.'},
#  {'sentence': 'Имеет одну жену, что странно (по самаршанским обычаям).',
#   'normalized_sentence': 'Имеет одну жену, что странно (по самаршанским обычаям).'},
#  {'sentence': '30 декабря 2012 года в третьем раунде нокаутировал безнадежно пробитого ямайца, Оуэна Бека.',
#   'normalized_sentence': 'тридцатого декабря две тысячи двенадцатого года в третьем раунде нокаутировал безнадежно пробитого ямайца, Оуэна Бека.'},
#  {'sentence': 'Официальный сайт группы « Элизиум » (19 декабря 2001).',
#   'normalized_sentence': 'Официальный сайт группы « Элизиум » (девятнадцатого декабря две тысячи первого года).'},
#  {'sentence': 'Официальный сайтНеофициальный сайт, фото, видео, музыка, форум и другое.',
#   'normalized_sentence': 'Официальный сайтНеофициальный сайт, фото, видео, музыка, форум и другое.'},
#  {'sentence': 'Административный центр — село Елантово.',
#   'normalized_sentence': 'Административный центр — село Елантово.'},
#  {'sentence': 'Она также символизирует единство целей островитян.',
#   'normalized_sentence': 'Она также символизирует единство целей островитян.'},
#  {'sentence': 'Черный цвет — добывающая промышленность, уголь, металлы.',
#   'normalized_sentence': 'Черный цвет — добывающая промышленность, уголь, металлы.'},
#  {'sentence': 'В своих работах « Прогресс: его законы и причины » и « Основные начала » (1860) он вводит понятие социального прогресса.',
#   'normalized_sentence': 'В своих работах « Прогресс: его законы и причины » и « Основные начала » (тысяча восемьсот шестьдесят) он вводит понятие социального прогресса.'},
#  {'sentence': 'Войска 3-го Белорусского фронта развивали стремительное наступление на Минском направлении.',
#   'normalized_sentence': 'Войска третьего Белорусского фронта развивали стремительное наступление на Минском направлении.'},
#  {'sentence': 'Однако она смогла встретиться во сне с Хироки, которого так сильно любит.',
#   'normalized_sentence': 'Однако она смогла встретиться во сне с Хироки, которого так сильно любит.'},
#  {'sentence': 'Фонд христиан - дегаров использует флаг с белым андреевским крестом, смещенным в верхний левый угол, с красным и зеленым полями.',
#   'normalized_sentence': 'Фонд христиан - дегаров использует флаг с белым андреевским крестом, смещенным в верхний левый угол, с красным и зеленым полями.'},
#  {'sentence': 'В пристройку с городовой лестницей также до недавнего времени нельзя было попасть.',
#   'normalized_sentence': 'В пристройку с городовой лестницей также до недавнего времени нельзя было попасть.'},
#  {'sentence': 'Подобная городовая лестница имелась и около Дмитровской башни.',
#   'normalized_sentence': 'Подобная городовая лестница имелась и около Дмитровской башни.'},
#  {'sentence': 'Эти функции выполнял Англо - Палестинский банк Еврейского национального агентства.',
#   'normalized_sentence': 'Эти функции выполнял Англо - Палестинский банк Еврейского национального агентства.'},
#  {'sentence': 'Перевод Яня Фу сильно повлиял на китайских ученых, потому что Янь Фу добавил национальные элементы, которых не было в оригинале.',
#   'normalized_sentence': 'Перевод Яня Фу сильно повлиял на китайских ученых, потому что Янь Фу добавил национальные элементы, которых не было в оригинале.'},
#  {'sentence': 'Миракли произошли из гимнов в честь святых и из чтения их житий в церкви.',
#   'normalized_sentence': 'Миракли произошли из гимнов в честь святых и из чтения их житий в церкви.'},
#  {'sentence': 'В 1954 году был образован Или - Казахский автономный округ, и Инин стал его столицей.',
#   'normalized_sentence': 'В тысяча девятьсот пятьдесят четвертом году был образован Или - Казахский автономный округ, и Инин стал его столицей.'},
#  {'sentence': 'Жуань Чунъу был членом ЦК КПК 13-го и 14-го созывов.',
#   'normalized_sentence': 'Жуань Чунъу был членом ц к к п к тринадцатого и четырнадцатого созывов.'},
#  {'sentence': 'Книга 1. — Псков, 2002. — Численность населения на 1 января 2001 года по сведениям, предоставленных администрациями районов.',
#   'normalized_sentence': 'Книга один. — Псков, две тысячи два. — Численность населения на первого января две тысячи первого года по сведениям, предоставленных администрациями районов.'},
#  {'sentence': 'Симптомы и синдромы.',
#   'normalized_sentence': 'Симптомы и синдромы.'},
#  {'sentence': 'В конце 50-х годов интенсивно развернулась теоретическая и методологическая работа в области социальной психологии.',
#   'normalized_sentence': 'В конце пятидесятых годов интенсивно развернулась теоретическая и методологическая работа в области социальной психологии.'},
#  {'sentence': 'Анк - су - намун затем убивает себя, прося Имхотепа воскресить ее.',
#   'normalized_sentence': 'Анк - су - намун затем убивает себя, прося Имхотепа воскресить ее.'},
#  {'sentence': 'Этот приказ был доведен политорганами советских войск до окруженных немецких солдат.',
#   'normalized_sentence': 'Этот приказ был доведен политорганами советских войск до окруженных немецких солдат.'},
#  {'sentence': 'Расстояние, которое он пролетел на середину декабря 2010 года, составляло приблизительно 116,38 а. е. (17,41 млрд км).',
#   'normalized_sentence': 'Расстояние, которое он пролетел на середину декабря две тысячи десятого года, составляло приблизительно сто шестнадцать целых и тридцать восемь сотых а. е. (семнадцать целых и сорок одна сотая миллиарда километров).'},
#  {'sentence': 'Они замаскировались и сняли комнату у торговца свечами, некоего мистера Дунбара.',
#   'normalized_sentence': 'Они замаскировались и сняли комнату у торговца свечами, некоего мистера Дунбара.'},
#  {'sentence': '25 августа 1906 — Член призового суда в Либаве.',
#   'normalized_sentence': 'двадцать пятого августа тысяча девятьсот шестого года — Член призового суда в Либаве.'},
#  {'sentence': 'Все навесы были убраны, чтобы провести реконструкцию первых этажей каждого здания, с целью восстановить традиционную архитектуру.',
#   'normalized_sentence': 'Все навесы были убраны, чтобы провести реконструкцию первых этажей каждого здания, с целью восстановить традиционную архитектуру.'},
#  {'sentence': 'Входит в экономико - статистический субрегион Бейра - Интериор - Норте, который входит в Центральный регион.',
#   'normalized_sentence': 'Входит в экономико - статистический субрегион Бейра - Интериор - Норте, который входит в Центральный регион.'},
#  {'sentence': 'М. В. Тронов выделил Белухинский ледниковый район в самостоятельный « тип ледников Белухи ».',
#   'normalized_sentence': 'м в Тронов выделил Белухинский ледниковый район в самостоятельный « тип ледников Белухи ».'},
#  {'sentence': 'Хотя инструмент с того времени видоизменился, но принцип остался тот же.',
#   'normalized_sentence': 'Хотя инструмент с того времени видоизменился, но принцип остался тот же.'},
#  {'sentence': '25 сентября 1918 г. он уехал в Горки, и вернулся в Москву 14 октября, сразу возобновив политическую деятельность.',
#   'normalized_sentence': 'двадцать пятого сентября тысяча девятьсот восемнадцатого года он уехал в Горки, и вернулся в Москву четырнадцатого октября, сразу возобновив политическую деятельность.'},
#  {'sentence': 'Ныне Свалява — известный бальнеологический курорт.',
#   'normalized_sentence': 'Ныне Свалява — известный бальнеологический курорт.'},
#  {'sentence': 'После освободительной войны 1703 — 1711 гг. город стал собственностью королевской казны и был подарен графу Шернборну - Бухгейму.',
#   'normalized_sentence': 'После освободительной войны тысяча семьсот три — тысяча семьсот одиннадцатый год город стал собственностью королевской казны и был подарен графу Шернборну - Бухгейму.'},
#  {'sentence': 'Французы присоединились к маркизу, пытались уйти в Акру, однако, когда Ричард воспрепятствовал этому, направились в Тир.',
#   'normalized_sentence': 'Французы присоединились к маркизу, пытались уйти в Акру, однако, когда Ричард воспрепятствовал этому, направились в Тир.'},
#  {'sentence': 'История любви в истории Франции.',
#   'normalized_sentence': 'История любви в истории Франции.'},
#  {'sentence': 'Сырьем для них служили крицы, выплавленные окрестными крестьянами в своих домницах из болотных руд.',
#   'normalized_sentence': 'Сырьем для них служили крицы, выплавленные окрестными крестьянами в своих домницах из болотных руд.'},
#  {'sentence': 'Завод по розливу минеральных вод действует в поселке Поляна.',
#   'normalized_sentence': 'Завод по розливу минеральных вод действует в поселке Поляна.'},
#  {'sentence': 'Все были уверены, что на этот раз Иерусалим будет взят.',
#   'normalized_sentence': 'Все были уверены, что на этот раз Иерусалим будет взят.'},
#  {'sentence': 'С рассветом противник пытался не допустить подвоза подкреплений на захваченный плацдарм, а затем уничтожить весь десант.',
#   'normalized_sentence': 'С рассветом противник пытался не допустить подвоза подкреплений на захваченный плацдарм, а затем уничтожить весь десант.'},
#  {'sentence': 'Крайняя слабость последнего короля Талигойи Эрнани Ракана привела к захвату власти узурпатором Франциском Олларом, впоследствии оказавшимся весьма сильным правителем.',
#   'normalized_sentence': 'Крайняя слабость последнего короля Талигойи Эрнани Ракана привела к захвату власти узурпатором Франциском Олларом, впоследствии оказавшимся весьма сильным правителем.'},
#  {'sentence': 'Земли 11688 дес.',
#   'normalized_sentence': 'Земли одиннадцать тысяч шестьсот восемьдесят восемь дес.'},
#  {'sentence': 'В бенгальском языке имеет дополнительное к описанному значение — « муж ».',
#   'normalized_sentence': 'В бенгальском языке имеет дополнительное к описанному значение — « муж ».'},
#  ...]

# %%
_punctuation = '!? ^,;.'
_letters = 'АБВГДЕЁЖЗИЙКЛМНҢОӨПРСТУҮФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнңоөпрстуүфхцчшщъыьэюя'
ALLOWED_CHARS = set(_punctuation + _letters)

def clean_and_format_text(text: str) -> str:
    """
    Applies two transformations to the input text:
    1. Converts the entire string to lowercase.
    2. Filters the string, keeping only the characters defined in ALLOWED_CHARS.
    """
    # Use a generator expression within "".join() for an efficient, one-line solution
    return "".join(char for char in text.lower() if char in ALLOWED_CHARS)


# --- 2. Convert to Gemma's Conversational Format ---
# The goal is to create a list where each item is a dictionary
# containing a single key "messages", and the value is the conversation list.
formatted_data = []
for item in results:
    conversation = [
        {'role': 'user', 'content': item['sentence']},
        {'role': 'assistant', 'content': clean_and_format_text(item['normalized_sentence'])}
    ]
    formatted_data.append({"messages": conversation})

print(f"Successfully converted {len(formatted_data)} items to the conversational format.")
print("Example of the new format:")
print(formatted_data[0])
# Out:
# Successfully converted 596921 items to the conversational format.
# Example of the new format:
# {'messages': [{'role': 'user', 'content': 'По состоянию на 1862 год.'}, {'role': 'assistant', 'content': 'по состоянию на тысяча восемьсот шестьдесят второй год.'}]}

# %%
# --- 3. Shuffle the Data ---
# This is a crucial step to ensure that the training and validation sets
# are representative of the overall data distribution.
# We set a seed for reproducibility.
import random
random.seed(42)
random.shuffle(formatted_data)
print("\nDataset has been shuffled.")
# Out:
# Dataset has been shuffled.

# %%
# --- 4. Create Train/Validation Split ---
# We'll use a 90/10 split as requested.
split_index = int(0.9 * len(formatted_data))
train_data = formatted_data[:split_index]
validation_data = formatted_data[split_index:]

print(f"Data split into {len(train_data)} training examples and {len(validation_data)} validation examples.")
# Out:
# Data split into 537228 training examples and 59693 validation examples.

# %%
from datasets import Dataset, DatasetDict
from huggingface_hub import notebook_login, whoami

# --- 5. Create a Hugging Face DatasetDict ---
# The `datasets` library works best with dictionaries of lists,
# so we convert our list of dicts into a dict of lists.
train_dataset = Dataset.from_dict({"messages": [item["messages"] for item in train_data]})
validation_dataset = Dataset.from_dict({"messages": [item["messages"] for item in validation_data]})

# Combine them into a single DatasetDict object
final_dataset = DatasetDict({
    'train': train_dataset,
    'validation': validation_dataset
})

print("\nCreated a Hugging Face DatasetDict:")
print(final_dataset)
# Out:
# Created a Hugging Face DatasetDict:
# DatasetDict({
#     train: Dataset({
#         features: ['messages'],
#         num_rows: 537228
#     })
#     validation: Dataset({
#         features: ['messages'],
#         num_rows: 59693
#     })
# })

# %%
# --- 6. Authenticate and Upload to Hugging Face Hub ---
print("\n--- Uploading to Hugging Face Hub ---")

# IMPORTANT: You need to be logged in.
# In a Jupyter/Colab notebook, use notebook_login().
# In a terminal, run `huggingface-cli login` before executing the script.
try:
    # Check if user is already logged in
    hf_username = whoami()['name']
    print(f"Authenticated as: {hf_username}")
except (OSError, KeyError):
    print("Not logged in. Please log in to Hugging Face.")
    # For notebooks, this will open a login widget
    notebook_login()
    hf_username = whoami()['name']

# **IMPORTANT**: Change this to your desired repository name!
# It should be in the format "your-username/your-dataset-name"
repo_id = f"kenenbek/gemma-russian-normalization-dataset" 

print(f"Preparing to upload the dataset to: https://huggingface.co/datasets/{repo_id}")

# Push the dataset to the Hub
# `private=True` makes the dataset private. Remove it or set to False for a public dataset.
final_dataset.push_to_hub(repo_id)

print("\n✅ Successfully uploaded the dataset to the Hugging Face Hub!")
# Out:
# --- Uploading to Hugging Face Hub ---
# Authenticated as: kenenbek
# Preparing to upload the dataset to: https://huggingface.co/datasets/kenenbek/gemma-russian-normalization-dataset
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✅ Successfully uploaded the dataset to the Hugging Face Hub!
